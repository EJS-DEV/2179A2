# %%
#

# %%
#

# %%
#

# %%
#
# Out:
# 36306

# %%
#from datetime import datetime
print (datetime.now())
# Out:
# 2023-08-23 15:42:57.557236

# %%
#

# %%
print (datetime.now())
# Out:
# 2023-08-23 15:43:05.568566

# %%
len(str(7 ** 7 ** 7))
# Out:
# 695975

# %%
#7 ** 7 ** 7

# %%
# 'NZ': ('New Zealand', (166.509144322, -46.641235447, 178.517093541, -34.4506617165)),
# 'AU': ('Australia', (113.338953078, -43.6345972634, 153.569469029, -10.6681857235)),
# Source: https://gist.github.com/graydon/11198540

# %%
#

# %%
#

# %%
import geopandas as gp
gb_tiles = gp.read_file("speedtest-ALL-Q322.geojson")

# %%
len(gb_tiles)
# Out:
# 5543845

# %%
from datetime import datetime
print (datetime.now())
# Out:
# 2024-01-08 11:41:02.892302

# %%
gb_tiles.describe()
# Out:
#          avg_d_kbps    avg_u_kbps    avg_lat_ms         tests       devices
# count  5.543845e+06  5.543845e+06  5.543845e+06  5.543845e+06  5.543845e+06
# mean   1.240633e+05  5.383261e+04  2.699138e+01  1.745842e+01  5.029403e+00
# std    1.315997e+05  7.939027e+04  6.716804e+01  9.757322e+01  1.287808e+01
# min    1.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.592700e+04  9.297000e+03  9.000000e+00  1.000000e+00  1.000000e+00
# 50%    7.282600e+04  2.385800e+04  1.500000e+01  4.000000e+00  2.000000e+00
# 75%    1.924840e+05  6.236200e+04  2.500000e+01  1.400000e+01  4.000000e+00
# max    2.076064e+06  1.725985e+06  2.882000e+03  1.418650e+05  1.259000e+03

# %%
print (datetime.now())
# Out:
# 2024-01-08 11:41:04.158787

# %%
#pip install ipywidgets

# %%
# need import ipywidgets first
from IPython.display import display
w = widgets.IntSlider()
display(w)
# Out:
# IntSlider(value=0)

# %%
# execute before create slider
import ipywidgets as widgets
###

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
a = 2 * w.value
a
# Out:
# 126

# %%
#au_tiles.loc[au_tiles['avg_d_kbps'] > 200000].centroid.plot()
# use slider to choose speed to display in plot
#gb_tiles = gp.read_file("speedtest-ALL-Q322.geojson")

# %matplotlib inline
# !pip install geopandas
# !pip install shapely
# !pip install rtree
# !apt-get install -y libspatialindex-dev
from datetime import datetime

import geopandas as gp
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from shapely.geometry import Point

# %%
#nz_tiles = gp.read_file("speedtest-NZ-Q323.geojson")
#au_tiles = gp.read_file("speedtest-AUS-Q323.geojson")
uk_tiles = gp.read_file("speedtest-UK-Q323.geojson")

# %%
len(nz_tiles) #21113
#len(au_tiles) #90249
#len(uk_tiles) #297666
# Out:
# 21113

# %%
#nz_tiles.centroid.plot()
#au_tiles.centroid.plot()
uk_tiles.centroid.plot()
# Out:
# /var/folders/0s/qxd9z2qd38lc_8yjl3wf1qjm36znn7/T/ipykernel_57752/843651906.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   uk_tiles.centroid.plot()
# <Axes: >

# %%
nz_tiles.loc[nz_tiles['avg_d_kbps'] > w.value].centroid.plot()
# Over slider speed
# recognisable at 400K
# Out:
# /var/folders/0s/qxd9z2qd38lc_8yjl3wf1qjm36znn7/T/ipykernel_13939/3439679140.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   nz_tiles.loc[nz_tiles['avg_d_kbps'] > w.value].centroid.plot()
# <Axes: >

# %%
from IPython.display import display
w = widgets.IntSlider(min=0,max=1000000,step=5)
display(w)
# https://ipywidgets.readthedocs.io/en/stable/examples/Using%20Interact.html#Widget-abbreviations
# Out:
# IntSlider(value=0, max=1000000, step=5)

# %%
def f(x):
    return x

# %%
#|interact(f, x=10);
print("speed is:",
    w.value, "kbps")
print("blocks under speed:",len(nz_tiles.loc[nz_tiles['avg_d_kbps'] < w.value]))
print("blocks over speed:",len(nz_tiles.loc[nz_tiles['avg_d_kbps'] > w.value]))
# Out:
# speed is: 51885 kbps
# blocks under speed: 5552
# blocks over speed: 15561

# %%
#interact(f, x=widgets.IntSlider(min=10, max=500000, step=1, value=10));

# %%
nz_tiles.loc[nz_tiles['avg_d_kbps'] < w.value].centroid.plot()
# under slider speed
# recognisable at 4k
# Out:
# /var/folders/0s/qxd9z2qd38lc_8yjl3wf1qjm36znn7/T/ipykernel_13939/3484903527.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   nz_tiles.loc[nz_tiles['avg_d_kbps'] < w.value].centroid.plot()
# <Axes: >

# %%
#len(nz_tiles.loc[nz_tiles['avg_d_kbps'] < w.value])
#nz_tiles['avg_d_mbps'] = nz_tiles['avg_d_kbps'] / 1000
#au_tiles['avg_d_mbps'] = au_tiles['avg_d_kbps'] / 1000
#uk_tiles['avg_d_mbps'] = uk_tiles['avg_d_kbps'] / 1000
#au_tiles.head()
#nz_tiles.head()
uk_tiles.head()
# Out:
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0  0311321033310101      108407       16891          51      6        2
# 1  0311321033311001      153050       15459          48      3        3
# 2  0311321112113300       80454       14114          46      1        1
# 3  0311321112203211       39594        6996          39      9        1
# 4  0311321112203213       40083        6305          38      1        1
#
#                                             geometry  avg_d_mbps
# 0  POLYGON ((-7.09167 58.17070, -7.08618 58.17070...     108.407
# 1  POLYGON ((-7.06970 58.17070, -7.06421 58.17070...     153.050
# 2  POLYGON ((-5.99854 58.59689, -5.99304 58.59689...      80.454
# 3  POLYGON ((-6.26770 58.50517, -6.26221 58.50517...      39.594
# 4  POLYGON ((-6.26770 58.50230, -6.26221 58.50230...      40.083

# %%
NZ_hist = Table().with_columns([
    'NZ', nz_tiles.avg_u_mbps.to_numpy()
])
NZ_hist.hist(bins=[0,25,50,75,100,250,500,1000])

# %%
from datascience import *
# pip install datascience

# %%
NZ_hist.select("NZ").hist(bins=np.arange(0,400,10))

# %%
NZ_hist.hist('NZ',bins = range(-5, 100))

# %%
NZ_hist.stats()
# Out:
# statistic | NZ
# min       | 0.073
# max       | 899.562
# median    | 140.562
# sum       | 3.25849e+06

# %%
#AUS = au_tiles.avg_u_mbps.to_numpy()
#AUS.sort()
AUS
# Out:
# array([  1.00000000e-03,   4.00000000e-03,   5.00000000e-03, ...,
#          6.13089000e+02,   7.66688000e+02,   7.72536000e+02])

# %%
NZ = nz_tiles.avg_d_mbps.to_numpy()
AUS = au_tiles.avg_d_mbps.to_numpy()
UK = uk_tiles.avg_d_mbps.to_numpy()

NZ.sort()
AUS.sort()
UK.sort()
fig = plt.figure(figsize=(5,5))
#ax = fig.add_subplot(2, 1, 1)
x1 = np.linspace(0,1,len(NZ))
x2 = np.linspace(0,1,len(AUS))
x3 = np.linspace(0,1,len(UK))


#ax.set_yscale('log')
plt.plot (x1, NZ, label="NZ")
plt.plot (x2, AUS, label="AUS")
plt.plot (x3, UK, label="UK")
plt.title("Comparing NZ/AUS/UK Broadband //Download// Distribution - Q3 2023")
#plt.title("Speedtest Open Data")


plt.xlabel("Proportion of users")
plt.ylabel("Mbps")
plt.legend(loc="best")
plt.ylim(0,900)

plt.show()

# can plot multiple lines over same scale, with scaled x axis. ie BKK, MEL, LAX, SHG - PICKUP
# plot of log scale
# bit rough and ready UK as includes some EIRE and FR in data - cut out using rectangle, so rought cut.

# %%
# %matplotlib inline

# %%
NZ_hist.hist(bins=25)

# %%
AUS_hist = Table().with_columns([
    'aus_u', au_tiles.avg_u_mbps.to_numpy()
])
AUS_hist.hist( bins=np.arange(0,200,10))

# %%
AUS_hist.where(aus_u >100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 AUS_hist.where(aus_u >100)
#
# NameError: name 'aus_u' is not defined

# %%
AUS_hist.where('aus_u', are.above(20))
#nba.where('SALARY', are.above(10))
# Out:
# aus_u
# 20.001
# 20.001
# 20.002
# 20.002
# 20.002
# 20.003
# 20.003
# 20.003
# 20.003
# 20.005
# ... (20911 rows omitted)

# %%
AUS_hist
# Out:
# aus_u
# 0.001
# 0.004
# 0.005
# 0.005
# 0.007
# 0.007
# 0.012
# 0.017
# 0.018
# 0.019
# ... (90239 rows omitted)
